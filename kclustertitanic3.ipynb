# %% [markdown]
# <a href="https://colab.research.google.com/github/Meghashyamt/python/blob/master/kclustertitanic3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

from sklearn.preprocessing import scale
from sklearn.preprocessing import normalize

# %%
data = pd.read_excel("titanic3.xls")
data.head()
# Out:
#    pclass  survived  ...   body                        home.dest
# 0       1         1  ...    NaN                     St Louis, MO
# 1       1         1  ...    NaN  Montreal, PQ / Chesterville, ON
# 2       1         0  ...    NaN  Montreal, PQ / Chesterville, ON
# 3       1         0  ...  135.0  Montreal, PQ / Chesterville, ON
# 4       1         0  ...    NaN  Montreal, PQ / Chesterville, ON
#
# [5 rows x 14 columns]

# %%
data.shape
# Out:
# (1309, 14)

# %%
data.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
data.fillna(data.mean())
# Out:
#       pclass  survived  ...        body                           home.dest
# 0          1         1  ...  160.809917                        St Louis, MO
# 1          1         1  ...  160.809917     Montreal, PQ / Chesterville, ON
# 2          1         0  ...  160.809917     Montreal, PQ / Chesterville, ON
# 3          1         0  ...  135.000000     Montreal, PQ / Chesterville, ON
# 4          1         0  ...  160.809917     Montreal, PQ / Chesterville, ON
# 5          1         1  ...  160.809917                        New York, NY
# 6          1         1  ...  160.809917                          Hudson, NY
# 7          1         0  ...  160.809917                         Belfast, NI
# 8          1         1  ...  160.809917                 Bayside, Queens, NY
# 9          1         0  ...   22.000000                 Montevideo, Uruguay
# 10         1         0  ...  124.000000                        New York, NY
# ...

# %%
data.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
data.ffill()
# Out:
#       pclass  survived  ...   body                           home.dest
# 0          1         1  ...    NaN                        St Louis, MO
# 1          1         1  ...    NaN     Montreal, PQ / Chesterville, ON
# 2          1         0  ...    NaN     Montreal, PQ / Chesterville, ON
# 3          1         0  ...  135.0     Montreal, PQ / Chesterville, ON
# 4          1         0  ...  135.0     Montreal, PQ / Chesterville, ON
# 5          1         1  ...  135.0                        New York, NY
# 6          1         1  ...  135.0                          Hudson, NY
# 7          1         0  ...  135.0                         Belfast, NI
# 8          1         1  ...  135.0                 Bayside, Queens, NY
# 9          1         0  ...   22.0                 Montevideo, Uruguay
# 10         1         0  ...  124.0                        New York, NY
# 11         1         1  ...  124.0                        New York, NY
# ...

# %%
data.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
from sklearn.cluster import KMeans

# %%
data.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
#data.dropna(inplace=True)

# %%
data1=data.loc[:,('pclass','survived','sibsp','parch')]

# %%
model= KMeans(n_clusters=3)

# %%
data2=scale(data1)
data2
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DataConversionWarning: Data with input dtype int64 were all converted to float64 by the scale function.
#   """Entry point for launching an IPython kernel.
# array([[-1.54609786,  1.27200629, -0.47908676, -0.4449995 ],
#        [-1.54609786,  1.27200629,  0.48128777,  1.86652569],
#        [-1.54609786, -0.78615963,  0.48128777,  1.86652569],
#        ...,
#        [ 0.84191642, -0.78615963, -0.47908676, -0.4449995 ],
#        [ 0.84191642, -0.78615963, -0.47908676, -0.4449995 ],
#        [ 0.84191642, -0.78615963, -0.47908676, -0.4449995 ]])

# %%
model.fit(data1)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
model.labels_
# Out:
# array([1, 1, 1, ..., 0, 0, 0], dtype=int32)

# %%
cluster= data.groupby('survived')

# %%
cluster.head()
# Out:
#    pclass  survived  ...   body                        home.dest
# 0       1         1  ...    NaN                     St Louis, MO
# 1       1         1  ...    NaN  Montreal, PQ / Chesterville, ON
# 2       1         0  ...    NaN  Montreal, PQ / Chesterville, ON
# 3       1         0  ...  135.0  Montreal, PQ / Chesterville, ON
# 4       1         0  ...    NaN  Montreal, PQ / Chesterville, ON
# 5       1         1  ...    NaN                     New York, NY
# 6       1         1  ...    NaN                       Hudson, NY
# 7       1         0  ...    NaN                      Belfast, NI
# 8       1         1  ...    NaN              Bayside, Queens, NY
# 9       1         0  ...   22.0              Montevideo, Uruguay
#
# [10 rows x 14 columns]

# %%
cluster.mean()
# Out:
#             pclass        age     sibsp     parch       fare        body
# survived
# 0         2.500618  30.545369  0.521632  0.328801  23.353831  160.809917
# 1         1.962000  28.918228  0.462000  0.476000  49.361184         NaN
