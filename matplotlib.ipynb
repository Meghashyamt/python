# %% [markdown]
# <a href="https://colab.research.google.com/github/Meghashyamt/python/blob/master/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x=np.linspace(0,5,10)
x
# Out:
# array([0.        , 0.55555556, 1.11111111, 1.66666667, 2.22222222,
#        2.77777778, 3.33333333, 3.88888889, 4.44444444, 5.        ])

# %%
y= x**2
y
plt.plot(x,y)
plt.plot(y,x)
plt.xlabel('this is x-axis')
plt.ylabel('this is y-axis')
plt.title('this is basic graph')
# Out:
# Text(0.5, 1.0, 'this is basic graph')

# %%
plt.subplot(1,2,1)
plt.plot(x,y)
plt.subplot(2,2,2)
plt.plot(y,x)
plt.subplot(2,2,4)
plt.plot(x,y)

# %%
#Object Oriented
fig=plt.figure()

# %%
fig=plt.figure(figsize=(9,5), dpi =100)
axes=fig.add_axes([0,0,1,1])
ax= fig.add_axes([0.6,0.6,0.3,0.3])
#left, bottom, width, height
ax.plot(y,x)


axes.plot(x,y)


axes.set_xlabel('X')

axes.set_ylabel('Y')

axes.set_title('Mygraph')
# Out:
# Text(0.5, 1.0, 'Mygraph')

# %%
f,ax=plt.subplots()
ax.plot(x,y)

# %%
f,ax=plt.subplots(nrows=1,ncols=2, figsize =(12,4), dpi=100)
ax[0].plot(x,y)
ax[0].set_title("plot1")
ax[0].set_xlabel("x axis")
ax[0].set_ylabel("y axis")


ax[1].plot(y,x)
ax[1].set_title("plot2")
ax[1].set_xlabel("x axis")
ax[1].set_ylabel("y axis")
plt.tight_layout()

# %%
#for saving
f.savefig("Myfig.png")

# %%
fig= plt.figure()
ax =fig.add_axes([0,0,1,1])
#ax.plot(x,y)
ax.plot((x, x+1))
ax.plot((x, x+2))
#ax.legends()
# Out:
# [<matplotlib.lines.Line2D at 0x7f0a508e7320>,
#  <matplotlib.lines.Line2D at 0x7f0a507446a0>,
#  <matplotlib.lines.Line2D at 0x7f0a507447f0>,
#  <matplotlib.lines.Line2D at 0x7f0a50744940>,
#  <matplotlib.lines.Line2D at 0x7f0a50744a90>,
#  <matplotlib.lines.Line2D at 0x7f0a50744be0>,
#  <matplotlib.lines.Line2D at 0x7f0a50744d30>,
#  <matplotlib.lines.Line2D at 0x7f0a50744e80>,
#  <matplotlib.lines.Line2D at 0x7f0a50744fd0>,
#  <matplotlib.lines.Line2D at 0x7f0a5074b160>]

# %%
plt.scatter(x,y)
