# %% [markdown]
# <a href="https://colab.research.google.com/github/Meghashyamt/python/blob/master/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x=np.linspace(0,5,10)
x
# Out:
# array([0.        , 0.55555556, 1.11111111, 1.66666667, 2.22222222,
#        2.77777778, 3.33333333, 3.88888889, 4.44444444, 5.        ])

# %%
y= x**2
y
plt.plot(x,y)
plt.plot(y,x)
plt.xlabel('this is x-axis')
plt.ylabel('this is y-axis')
plt.title('this is basic graph')
# Out:
# Text(0.5, 1.0, 'this is basic graph')

# %%
plt.subplot(1,2,1)
plt.plot(x,y)
plt.subplot(2,2,2)
plt.plot(y,x)
plt.subplot(2,2,4)
plt.plot(x,y)

# %%
#Object Oriented
fig=plt.figure()

# %%
fig=plt.figure(figsize=(9,5), dpi =100)
axes=fig.add_axes([0,0,1,1])
ax= fig.add_axes([0.6,0.6,0.3,0.3])
#left, bottom, width, height
ax.plot(y,x)


axes.plot(x,y)


axes.set_xlabel('X')

axes.set_ylabel('Y')

axes.set_title('Mygraph')
# Out:
# Text(0.5, 1.0, 'Mygraph')

# %%
f,ax=plt.subplots()
ax.plot(x,y)

# %%
f,ax=plt.subplots(nrows=1,ncols=2, figsize =(12,4), dpi=100)
ax[0].plot(x,y)
ax[0].set_title("plot1")
ax[0].set_xlabel("x axis")
ax[0].set_ylabel("y axis")


ax[1].plot(y,x)
ax[1].set_title("plot2")
ax[1].set_xlabel("x axis")
ax[1].set_ylabel("y axis")
plt.tight_layout()

# %%
#for saving
f.savefig("Myfig.png")

# %%
fig= plt.figure()
ax =fig.add_axes([0,0,1,1])
#ax.plot(x,y)
ax.plot((x, x+1))
ax.plot((x, x+2))
#ax.legends()
# Out:
# [<matplotlib.lines.Line2D at 0x7f535262ec88>,
#  <matplotlib.lines.Line2D at 0x7f53526004a8>,
#  <matplotlib.lines.Line2D at 0x7f53526005f8>,
#  <matplotlib.lines.Line2D at 0x7f5352600748>,
#  <matplotlib.lines.Line2D at 0x7f5352600898>,
#  <matplotlib.lines.Line2D at 0x7f53526009e8>,
#  <matplotlib.lines.Line2D at 0x7f5352600b38>,
#  <matplotlib.lines.Line2D at 0x7f5352600c88>,
#  <matplotlib.lines.Line2D at 0x7f5352600dd8>,
#  <matplotlib.lines.Line2D at 0x7f5352600f28>]

# %%
plt.scatter(x,y)

# %%
plt.plot(x,y, 'r')
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r--')
plt.subplot(1,2,2)
plt.plot(y,x, 'g*-')

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,1,1])
plt.plot(x,y,'b')

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,1,1])
axes1=fig.add_axes([0.2,0.5,0.4,0.4])
axes.plot(x,y,'r')
axes1.plot(y,x,'b')

# %%
fig, axes =plt.subplots()
plt.plot(x,y,'r')

# %%
fig, axes = plt.subplots(nrows=1,ncols=2)

# %%
for ax in axes:
  ax.plot(x,y)

# %%
fig

# %%
fig.savefig("test.png")

# %%
fig= plt.figure(figsize=(12,3), dpi =100)
axes=fig.add_axes([0,0,1,1])
axes.plot(x,x**2, label ="x")
axes.plot(y,y**3, label="y")
ax.legend()
# Out:
# No handles with labels found to put in legend.

# %%
plt.plot(x,y)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("my graph")


plt.subplot(1,2,1)
plt.xlim(0,3)
plt.plot(x,y)
plt.ylim(0,3)
plt.subplot(1,2,2)
plt.plot(y,x)
plt.ylim(0,3)
plt.xlim(0,3)
# Out:
# (0, 3)

# %%
fig=plt.figure()
z=y**2
axes=fig.add_axes([0,0,1,1])
axes.plot(x,y)
axes.set_xlabel("x axis")
axes1=fig.add_axes([0.2,0.5,0.3,0.4])
axes1.plot(x,z)

# %%
plt.subplot(1,2,1)
plt.xlim(0,3)
plt.plot(x,y)
plt.ylim(0,3)
plt.subplot(2,2,3)
plt.plot(y,x)
plt.ylim(0,3)
plt.xlim(0,3)
plt.subplot(2,2,2)
plt.plot(y,x)
plt.ylim(0,3)
plt.xlim(0,3)
plt.subplot(2,2,4)
plt.xlim(0,3)
plt.plot(x,z)
plt.ylim(0,3)
# Out:
# (0, 3)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
#fig, axes1 = plt.subplots(nrows=1, ncols=2)

# Now use the axes object to add stuff to plot
axes[0].plot(x, y, 'r')
axes[1].plot(y,x)
axes[0].set_xlabel('x')
axes[0].set_ylabel('y')
axes[0].set_title('title');

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax1 = fig.add_axes([1,0,1,1])

ax.plot(x, x**2, label="x**2")
ax1.plot(x, x**3, label="x**3")
ax.legend(loc=3)
ax1.legend(loc=2)

# %%
from sqlalchemy import create_engine
