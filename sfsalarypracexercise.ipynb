# %% [markdown]
# <a href="https://colab.research.google.com/github/Meghashyamt/python/blob/master/sfsalarypracexercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
sal= pd.read_csv("Salaries.csv")

# %%
sal.head(300)
# Out:
#       Id        EmployeeName  \
# 0      1      NATHANIEL FORD
# 1      2        GARY JIMENEZ
# 2      3      ALBERT PARDINI
# 3      4   CHRISTOPHER CHONG
# 4      5     PATRICK GARDNER
# 5      6      DAVID SULLIVAN
# 6      7           ALSON LEE
# 7      8       DAVID KUSHNER
# 8      9      MICHAEL MORRIS
# 9     10  JOANNE HAYES-WHITE
# 10    11       ARTHUR KENNEY
# 11    12    PATRICIA JACKSON
# 12    13   EDWARD HARRINGTON
# 13    14         JOHN MARTIN
# 14    15      DAVID FRANKLIN
# 15    16     RICHARD CORRIEA
# 16    17            AMY HART
# 17    18      SEBASTIAN WONG
# 18    19          MARTY ROSS
# 19    20       ELLEN MOFFATT
# 20    21          VENUS AZAR
# 21    22        JUDY MELINEK
# 22    23       GEORGE GARCIA
# 23    24       VICTOR WYRSCH
# 24    25     JOSEPH DRISCOLL
# 25    26        GREGORY SUHR
# 26    27         JOHN HANLEY
# 27    28      RAYMOND GUZMAN
# 28    29      DENISE SCHMITT
# 29    30       MONICA FIELDS
# ..   ...                 ...
# ...

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30362 entries, 0 to 30361
# Data columns (total 13 columns):
# Id                  30362 non-null int64
# EmployeeName        30361 non-null object
# JobTitle            30361 non-null object
# BasePay             30361 non-null float64
# OvertimePay         30361 non-null float64
# OtherPay            30361 non-null float64
# Benefits            0 non-null float64
# TotalPay            30361 non-null float64
# TotalPayBenefits    30361 non-null float64
# Year                30361 non-null float64
# Notes               0 non-null float64
# Agency              30361 non-null object
# Status              0 non-null float64
# dtypes: float64(9), int64(1), object(3)
# memory usage: 3.0+ MB

# %%
sal['BasePay'].mean()
# Out:
# 74696.90481835336

# %%
sal['OvertimePay'].max()
# Out:
# 245131.88

# %%
df = sal[sal.EmployeeName == 'JOSEPH DRISCOLL']
df.loc[:,'JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %%
df = sal[sal.EmployeeName == 'JOSEPH DRISCOLL']
df.loc[:,'TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %%
#df = sal['TotalPay'].max()
#df.loc[:,'EmployeeName']

# %%
df=sal['EmployeeName'][sal.TotalPay==sal.TotalPay.max()]
df
# Out:
# 0    NATHANIEL FORD
# Name: EmployeeName, dtype: object

# %%
df =sal[(sal.Year>=2011) & (sal.Year>=2014)]
df.loc[:,('BasePay')]
# Out:
# Series([], Name: BasePay, dtype: float64)

# %%
sum(sal[sal['Year'] == 2013]['JobTitle'].value_counts() == 1)
# Out:
# 0

# %%
def chief_string(title):
if 'chief' in title.lower().split():
return True
elif 'chief,' in title.lower().split():
return True
else:
return False

# %%
comm= pd.read_csv("Ecommerce Purchases.csv")
comm.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
comm.shape
# Out:
# (10000, 14)

# %%
comm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
# Address             10000 non-null object
# Lot                 10000 non-null object
# AM or PM            10000 non-null object
# Browser Info        10000 non-null object
# Company             10000 non-null object
# Credit Card         10000 non-null int64
# CC Exp Date         10000 non-null object
# CC Security Code    10000 non-null int64
# CC Provider         10000 non-null object
# Email               10000 non-null object
# Job                 10000 non-null object
# IP Address          10000 non-null object
# Language            10000 non-null object
# Purchase Price      10000 non-null float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
comm['Purchase Price'].mean()
# Out:
# 50.34730200000025

# %%
comm['Purchase Price'].max()
# Out:
# 99.99

# %%
comm['Purchase Price'].min()
# Out:
# 0.0

# %%
comm[comm['Language']=='en'].count()
# Out:
# Address             1098
# Lot                 1098
# AM or PM            1098
# Browser Info        1098
# Company             1098
# Credit Card         1098
# CC Exp Date         1098
# CC Security Code    1098
# CC Provider         1098
# Email               1098
# Job                 1098
# IP Address          1098
# Language            1098
# Purchase Price      1098
# dtype: int64
